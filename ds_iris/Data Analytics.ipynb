# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# describe the data and print its shape, info and other necessary information
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# shape
df.shape
# Out:
# (150, 5)

# %%
# check if it has null values

df.isnull().sum() # none are there  if there was you impute df.fillna(0)
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#  Analyze the Sepal Length ( create atleast 3 graphs) - you can google
"""
    Sepal_length is numeric data:
        Analytics - mean, median, min, max
        Graphs - histogram, boxplot
"""
sepal_len = df.sepal_length
print({'mean':sepal_len.mean(), 'min':sepal_len.min(), 'median':sepal_len.median(), 'max':sepal_len.max()})

sepal_len.plot(kind='hist')
# Out:
# {'mean': 5.843333333333334, 'min': 4.3, 'median': 5.8, 'max': 7.9}
# <AxesSubplot:ylabel='Frequency'>

# %%
# second graph
sepal_len.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Third graph
import seaborn as sns
sns.distplot(sepal_len)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
# analyze Species (create atleast 3 graphs) - you can google also
"""
    Species : Non-numerical data
        analytics - value counts
        graphs - bar, chart, line

"""
spec = df.species

spec.value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
# Graph 1 - bar
spec.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Second Graph
spec.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='species'>

# %%
# Third Graph
spec.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# analyze "Sepal Length" and "Sepal Width"
sepal_w = df.sepal_width
correlation = sepal_len.corr(sepal_w)

print(correlation)

sns.heatmap()
# Out:
# -0.10936924995064937

# %%
# sepal length graphs
sepal_w.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# sepal length histogram
sepal_w.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# analyze "Species " and "PEtal Witdth" using groupbys
#  create a graph of the groupby
df.groupby('species').petal_width.agg(['mean', 'max', 'min','median'])
# Out:
#              mean  max  min  median
# species
# setosa      0.244  0.6  0.1     0.2
# versicolor  1.326  1.8  1.0     1.3
# virginica   2.026  2.5  1.4     2.0

# %%
df.groupby('species').petal_width.agg(['mean', 'max', 'min','median']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='species'>

# %%
# create a scatter plot in seaborn for the Sepal_length and Petal_length, add the Species as the color
# I have done this for you to demostrate how you can use  three columns to create a graph

plt.figure(figsize=(9,7))
sns.scatterplot(data= df,x = 'sepal_length',y = 'petal_length',hue = "species")
plt.title('The distribution of Species')
plt.show()

# %%
# create a prime number function takes in a number and returns all the prime numbers between 0 and that number
def get_prime(n):
    output = []
    for i in range(0, n):
        if i ==2:
            return false
        
        if i % 2 != 0:
            output.append(i)
        if i % 3 != 0:
            output.append(i)

# %%
# create a forloop that goes through petal length and sepal length if both are greater than the average, 
# it prints "great" else  prints "not great"
new_field = [*df.petal_length, *df.sepal_length]
len(new_field)
import numpy as np

new_array = np.array(new_field)
average = new_array.mean()

for item in new_array:
    if item > average:
        print({item:'great'})
    else:
        print({item:'not great'})
# Out:
# {1.4: 'not great'}
# {1.4: 'not great'}
# {1.3: 'not great'}
# {1.5: 'not great'}
# {1.4: 'not great'}
# {1.7: 'not great'}
# {1.4: 'not great'}
# {1.5: 'not great'}
# {1.4: 'not great'}
# {1.5: 'not great'}
# {1.5: 'not great'}
# {1.6: 'not great'}
# {1.4: 'not great'}
# {1.1: 'not great'}
# {1.2: 'not great'}
# {1.5: 'not great'}
# {1.3: 'not great'}
# {1.4: 'not great'}
# {1.7: 'not great'}
# {1.5: 'not great'}
# {1.7: 'not great'}
# {1.5: 'not great'}
# {1.0: 'not great'}
# {1.7: 'not great'}
# {1.9: 'not great'}
# {1.6: 'not great'}
# {1.6: 'not great'}
# {1.5: 'not great'}
# {1.4: 'not great'}
# {1.6: 'not great'}
# {1.6: 'not great'}
# {1.5: 'not great'}
# {1.5: 'not great'}
# {1.4: 'not great'}
# {1.5: 'not great'}
# {1.2: 'not great'}
# {1.3: 'not great'}
# {1.5: 'not great'}
# {1.3: 'not great'}
# {1.5: 'not great'}
# {1.3: 'not great'}
# {1.3: 'not great'}
# {1.3: 'not great'}
# {1.6: 'not great'}
# {1.9: 'not great'}
# {1.4: 'not great'}
# {1.6: 'not great'}
# {1.4: 'not great'}
# {1.5: 'not great'}
# {1.4: 'not great'}
# {4.7: 'not great'}
# {4.5: 'not great'}
# {4.9: 'great'}
# {4.0: 'not great'}
# {4.6: 'not great'}
# {4.5: 'not great'}
# {4.7: 'not great'}
# {3.3: 'not great'}
# {4.6: 'not great'}
# {3.9: 'not great'}
# {3.5: 'not great'}
# {4.2: 'not great'}
# {4.0: 'not great'}
# {4.7: 'not great'}
# {3.6: 'not great'}
# {4.4: 'not great'}
# {4.5: 'not great'}
# {4.1: 'not great'}
# {4.5: 'not great'}
# {3.9: 'not great'}
# {4.8: 'not great'}
# {4.0: 'not great'}
# {4.9: 'great'}
# {4.7: 'not great'}
# {4.3: 'not great'}
# {4.4: 'not great'}
# {4.8: 'not great'}
# {5.0: 'great'}
# {4.5: 'not great'}
# {3.5: 'not great'}
# {3.8: 'not great'}
# {3.7: 'not great'}
# {3.9: 'not great'}
# {5.1: 'great'}
# {4.5: 'not great'}
# {4.5: 'not great'}
# {4.7: 'not great'}
# {4.4: 'not great'}
# {4.1: 'not great'}
# {4.0: 'not great'}
# {4.4: 'not great'}
# {4.6: 'not great'}
# {4.0: 'not great'}
# {3.3: 'not great'}
# {4.2: 'not great'}
# {4.2: 'not great'}
# {4.2: 'not great'}
# {4.3: 'not great'}
# {3.0: 'not great'}
# {4.1: 'not great'}
# {6.0: 'great'}
# {5.1: 'great'}
# {5.9: 'great'}
# {5.6: 'great'}
# {5.8: 'great'}
# {6.6: 'great'}
# {4.5: 'not great'}
# {6.3: 'great'}
# {5.8: 'great'}
# {6.1: 'great'}
# {5.1: 'great'}
# {5.3: 'great'}
# {5.5: 'great'}
# {5.0: 'great'}
# {5.1: 'great'}
# {5.3: 'great'}
# {5.5: 'great'}
# {6.7: 'great'}
# {6.9: 'great'}
# {5.0: 'great'}
# {5.7: 'great'}
# {4.9: 'great'}
# {6.7: 'great'}
# {4.9: 'great'}
# {5.7: 'great'}
# {6.0: 'great'}
# {4.8: 'not great'}
# {4.9: 'great'}
# {5.6: 'great'}
# {5.8: 'great'}
# {6.1: 'great'}
# {6.4: 'great'}
# {5.6: 'great'}
# {5.1: 'great'}
# {5.6: 'great'}
# {6.1: 'great'}
# {5.6: 'great'}
# {5.5: 'great'}
# {4.8: 'not great'}
# {5.4: 'great'}
# {5.6: 'great'}
# {5.1: 'great'}
# {5.1: 'great'}
# {5.9: 'great'}
# {5.7: 'great'}
# {5.2: 'great'}
# {5.0: 'great'}
# {5.2: 'great'}
# {5.4: 'great'}
# {5.1: 'great'}
# {5.1: 'great'}
# {4.9: 'great'}
# {4.7: 'not great'}
# {4.6: 'not great'}
# {5.0: 'great'}
# {5.4: 'great'}
# {4.6: 'not great'}
# {5.0: 'great'}
# {4.4: 'not great'}
# {4.9: 'great'}
# {5.4: 'great'}
# {4.8: 'not great'}
# {4.8: 'not great'}
# {4.3: 'not great'}
# {5.8: 'great'}
# {5.7: 'great'}
# {5.4: 'great'}
# {5.1: 'great'}
# {5.7: 'great'}
# {5.1: 'great'}
# {5.4: 'great'}
# {5.1: 'great'}
# {4.6: 'not great'}
# {5.1: 'great'}
# {4.8: 'not great'}
# {5.0: 'great'}
# {5.0: 'great'}
# {5.2: 'great'}
# {5.2: 'great'}
# {4.7: 'not great'}
# {4.8: 'not great'}
# {5.4: 'great'}
# {5.2: 'great'}
# {5.5: 'great'}
# {4.9: 'great'}
# {5.0: 'great'}
# {5.5: 'great'}
# {4.9: 'great'}
# {4.4: 'not great'}
# {5.1: 'great'}
# {5.0: 'great'}
# {4.5: 'not great'}
# {4.4: 'not great'}
# {5.0: 'great'}
# {5.1: 'great'}
# {4.8: 'not great'}
# {5.1: 'great'}
# {4.6: 'not great'}
# {5.3: 'great'}
# {5.0: 'great'}
# {7.0: 'great'}
# {6.4: 'great'}
# {6.9: 'great'}
# {5.5: 'great'}
# {6.5: 'great'}
# {5.7: 'great'}
# {6.3: 'great'}
# {4.9: 'great'}
# {6.6: 'great'}
# {5.2: 'great'}
# {5.0: 'great'}
# {5.9: 'great'}
# {6.0: 'great'}
# {6.1: 'great'}
# {5.6: 'great'}
# {6.7: 'great'}
# {5.6: 'great'}
# {5.8: 'great'}
# {6.2: 'great'}
# {5.6: 'great'}
# {5.9: 'great'}
# {6.1: 'great'}
# {6.3: 'great'}
# {6.1: 'great'}
# {6.4: 'great'}
# {6.6: 'great'}
# {6.8: 'great'}
# {6.7: 'great'}
# {6.0: 'great'}
# {5.7: 'great'}
# {5.5: 'great'}
# {5.5: 'great'}
# {5.8: 'great'}
# {6.0: 'great'}
# {5.4: 'great'}
# {6.0: 'great'}
# {6.7: 'great'}
# {6.3: 'great'}
# {5.6: 'great'}
# {5.5: 'great'}
# {5.5: 'great'}
# {6.1: 'great'}
# {5.8: 'great'}
# {5.0: 'great'}
# {5.6: 'great'}
# {5.7: 'great'}
# {5.7: 'great'}
# {6.2: 'great'}
# {5.1: 'great'}
# {5.7: 'great'}
# {6.3: 'great'}
# {5.8: 'great'}
# {7.1: 'great'}
# {6.3: 'great'}
# {6.5: 'great'}
# {7.6: 'great'}
# {4.9: 'great'}
# {7.3: 'great'}
# {6.7: 'great'}
# {7.2: 'great'}
# {6.5: 'great'}
# {6.4: 'great'}
# {6.8: 'great'}
# {5.7: 'great'}
# {5.8: 'great'}
# {6.4: 'great'}
# {6.5: 'great'}
# {7.7: 'great'}
# {7.7: 'great'}
# {6.0: 'great'}
# {6.9: 'great'}
# {5.6: 'great'}
# {7.7: 'great'}
# {6.3: 'great'}
# {6.7: 'great'}
# {7.2: 'great'}
# {6.2: 'great'}
# {6.1: 'great'}
# {6.4: 'great'}
# {7.2: 'great'}
# {7.4: 'great'}
# {7.9: 'great'}
# {6.4: 'great'}
# {6.3: 'great'}
# {6.1: 'great'}
# {7.7: 'great'}
# {6.3: 'great'}
# {6.4: 'great'}
# {6.0: 'great'}
# {6.9: 'great'}
# {6.7: 'great'}
# {6.9: 'great'}
# {5.8: 'great'}
# {6.8: 'great'}
# {6.7: 'great'}
# {6.7: 'great'}
# {6.3: 'great'}
# {6.5: 'great'}
# {6.2: 'great'}
# {5.9: 'great'}
